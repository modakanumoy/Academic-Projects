# %%
import pandas as p

calorie_dataset = p.read_csv("C:/Users/LENOVO/OneDrive/Desktop/python for data analysis/data_panada.csv")
print(calorie_dataset)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
from sympy import true


calorie_dataset = p.read_csv('data-clean.csv')
cal = 1000000  #calorie_dataset['Calories'].mean()

calorie_dataset.fillna({'Calories':cal},inplace= True)
print(calorie_dataset)
# Out:
#     Duration        date  Pulse  Maxpulse   Calories
# 0         60  01-08-2023    110       130      409.1
# 1         60  02-08-2023    117       145      479.0
# 2         60  03-08-2023    103       135      340.0
# 3         45  04-08-2023    109       175      282.4
# 4         45  05-08-2023    117       148      406.0
# 5         60  06-08-2023    102       127      300.0
# 6         60  07-08-2023    110       136      374.0
# 7        450  08-08-2023    104       134      253.3
# 8         30  09-08-2023    109       133      195.1
# 9         60  10-08-2023     98       124      269.0
# 10        60  11-08-2023    103       147      329.3
# 11        60  12-08-2023    100       120      250.7
# 12        60  12-08-2023    100       120      250.7
# 13        60  14-08-2023    104       132      379.3
# 14        60  15-08-2023     98       123      275.0
# 15        60  16-08-2023     98       120      215.2
# 16        60  17-08-2023    100       120      300.0
# ...

# %%
calorie_dataset.loc[7,'Duration'] =30
print(calorie_dataset.to_string())
# Out:
#     Duration        date  Pulse  Maxpulse   Calories
# 0         60  01-08-2023    110       130      409.1
# 1         60  02-08-2023    117       145      479.0
# 2         60  03-08-2023    103       135      340.0
# 3         45  04-08-2023    109       175      282.4
# 4         45  05-08-2023    117       148      406.0
# 5         60  06-08-2023    102       127      300.0
# 6         60  07-08-2023    110       136      374.0
# 7         30  08-08-2023    104       134      253.3
# 8         30  09-08-2023    109       133      195.1
# 9         60  10-08-2023     98       124      269.0
# 10        60  11-08-2023    103       147      329.3
# 11        60  12-08-2023    100       120      250.7
# 12        60  12-08-2023    100       120      250.7
# 13        60  14-08-2023    104       132      379.3
# 14        60  15-08-2023     98       123      275.0
# 15        60  16-08-2023     98       120      215.2
# 16        60  17-08-2023    100       120      300.0
# ...

# %%
calorie_dataset.loc[7,'Duration'] =30
print(calorie_dataset.to_string())
# Out:
#     Duration        date  Pulse  Maxpulse   Calories
# 0         60  01-08-2023    110       130      409.1
# 1         60  02-08-2023    117       145      479.0
# 2         60  03-08-2023    103       135      340.0
# 3         45  04-08-2023    109       175      282.4
# 4         45  05-08-2023    117       148      406.0
# 5         60  06-08-2023    102       127      300.0
# 6         60  07-08-2023    110       136      374.0
# 7         30  08-08-2023    104       134      253.3
# 8         30  09-08-2023    109       133      195.1
# 9         60  10-08-2023     98       124      269.0
# 10        60  11-08-2023    103       147      329.3
# 11        60  12-08-2023    100       120      250.7
# 12        60  12-08-2023    100       120      250.7
# 13        60  14-08-2023    104       132      379.3
# 14        60  15-08-2023     98       123      275.0
# 15        60  16-08-2023     98       120      215.2
# 16        60  17-08-2023    100       120      300.0
# ...

# %%
import
import matplotlib as plot



calorie_dataset = p.read_csv('Data.csv')

calorie_dataset.plot()
# Out:
#   Cell In[18], line 1
#     import
#           ^
# SyntaxError: invalid syntax
